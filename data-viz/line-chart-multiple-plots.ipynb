# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Two functions that will be used frequently with the data from the federal reserve
# py.plot()
# py.show()

# %%
plt.plot()
# Out:
# []

# %%
plt.show()

# %%
unrate = pd.read_csv('UNRATE.csv')
unrate['DATE'] = pd.to_datetime(unrate['DATE'])
unrate
# Out:
#           DATE  UNRATE
# 0   1948-01-01     3.4
# 1   1948-02-01     3.8
# 2   1948-03-01     4.0
# 3   1948-04-01     3.9
# 4   1948-05-01     3.5
# ..         ...     ...
# 868 2020-05-01    13.3
# 869 2020-06-01    11.1
# 870 2020-07-01    10.2
# 871 2020-08-01     8.4
# 872 2020-09-01     7.9
#
# [873 rows x 2 columns]

# %%
#Matplotlib will accept any iterable object, like NumPy arrays and pandas.Series instances.
plt.plot(x_values,y_values)

# %%
x = unrate['DATE']
y = unrate['UNRATE']
plt.plot(x,y)

# %%
first_twelve = unrate[0:12]
plt.plot(first_twelve['DATE'], first_twelve['UNRATE'])

# %%
plt.plot(first_twelve['DATE'], first_twelve['UNRATE'])
plt.show()

# %% [markdown]
# To change the labels: see documentation: https://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.xticks
# you can change xticks and yticks

# %%
xfirst_twelve = unrate[0:12]
plt.plot(first_twelve['DATE'], first_twelve['UNRATE'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Here's an overview of the pyplot functions we need to tweak the axis labels and the plot title:
#
#     xlabel(): accepts a string value, which gets set as the x-axis label.
#     ylabel(): accepts a string value, which is set as the y-axis label.
#     title(): accepts a string value, which is set as the plot title.

# %%
first_twelve = unrate[0:12]
plt.plot(first_twelve['DATE'], first_twelve['UNRATE'])
plt.xticks(rotation=90)
plt.xlabel('Month')
plt.ylabel('Unemployment Rate')
plt.title('Monthly Unemployment Trends, 1948')

plt.show()

# %% [markdown]
# <h2>Multiple Plots

# %%
#creates 2 rows, 2 columns and the last number is the index or axes (the subplot number such as 1st, 2nd, 3rd.. etc.)
fig = plt.figure()
ax1 = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2)

# %%
#so now 2 rows, 2 columns and 4 subplots
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

# %%
#leave one blaknk without axes 
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax1 = fig.add_subplot(2,2,3)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2)

ax1.plot(unrate[0:12]['DATE'],unrate[0:12]['UNRATE'])
ax2.plot(unrate[12:24]['DATE'],unrate[12:24]['UNRATE'])
plt.show()

# %%
fig = plt.figure(figsize=(12,5))
ax1 = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2)
ax1.plot(unrate[0:12]['DATE'], unrate[0:12]['UNRATE'])
ax1.set_title('Monthly Unemployment Rate, 1948')
ax2.plot(unrate[12:24]['DATE'], unrate[12:24]['UNRATE'])
ax2.set_title('Monthly Unemployment Rate, 1949')
plt.show()

# %%
#now create 5 rows on column for 5 years of monthly unemployment data
fig = plt.figure(figsize=(12,12))

for i in range(5):
    ax = fig.add_subplot(5,1,i+1)
    start_index = i*12
    end_index = (i+1)*12
    date_range = unrate[start_index:end_index]
    ax.plot(date_range['DATE'],date_range['UNRATE'])
    
plt.show()

# %% [markdown]
# <h2>You can add multiple plots to a subplot or multiple plots to the base subplot which is the initialized subplot when creating the figure class, see below:

# %% [markdown]
# <h3> We will also use the datetime module, to extract the month values from the DATE column and assign them to a new column, we can use the pandas.Series.dt accessor:
#     unrate['MONTH'] = unrate['DATE'].dt.month

# %%
unrate['MONTH'] = unrate['DATE'].dt.month
fig = plt.figure(figsize=(6,3))
plt.plot(unrate[0:12]['MONTH'],unrate[0:12]['UNRATE'], c='red')
plt.plot(unrate[12:24]['MONTH'], unrate[12:24]['UNRATE'], c='blue')

plt.show()

# %%
#use a loop to plot multiple plots on a base subplot with different colors:
fig = plt.figure(figsize=(10,6))
colors = ['red','blue','green','orange','black']
for i in range(5):
    start_index = i*12
    end_index = (i+1)*12
    date_range = unrate[start_index:end_index]
    plt.plot(date_range['MONTH'],date_range["UNRATE"],c=colors[i])
    
plt.show()

# %% [markdown]
# <h3>Can see that we don't know which are which colors so add legend

# %% [markdown]
# <h4> Add label to each line by plt.plot(unrate[0:12]['MONTH'], unrate[0:12]['VALUE'], c='red', label='1948')
# plt.plot(unrate[12:24]['MONTH'], unrate[12:24]['VALUE'], c='blue', label='1949')

# %%
#add legend and label
fig = plt.figure(figsize=(10,6))
colors = ['red', 'blue', 'green', 'orange', 'black']

for i in range(5):
    start_index = i*12
    end_index = (i+1)*12
    subset = unrate[start_index:end_index]
    label = 1948 + i
    plt.plot(subset['MONTH'], subset['UNRATE'], c=colors[i], label=label)

plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# <h3>Add titles to the axes

# %%
fig = plt.figure(figsize=(10,6))
colors = ['red', 'blue', 'green', 'orange', 'black']
for i in range(5):
    start_index = i*12
    end_index = (i+1)*12
    subset = unrate[start_index:end_index]
    label = str(1948 + i)
    plt.plot(subset['MONTH'], subset['UNRATE'], c=colors[i], label=label)
    
plt.title("Monthly Unemployment Trends, 1948-1952")
plt.xlabel("Month, Integer")
plt.ylabel("Unemployment Rate, Percent")
plt.legend(loc='upper left')

plt.show()

# %% [markdown]
# <h2>Bar plots and scatter plots

# %%
from numpy import arange
import pandas as pd

# %%
reviews = pd.read_csv('fandango_score_comparison.csv')
reviews.head(3)
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
#
#    Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0          66              7.1   7.8             5.0                   4.5
# 1          67              7.5   7.1             5.0                   4.5
# 2          64              8.1   7.8             5.0                   4.5
#
#    RT_norm  RT_user_norm  ...  IMDB_norm  RT_norm_round  RT_user_norm_round  \
# 0     3.70           4.3  ...       3.90            3.5                 4.5
# 1     4.25           4.0  ...       3.55            4.5                 4.0
# 2     4.00           4.5  ...       3.90            4.0                 4.5
#
# ...

# %%
norm_reviews = pd.DataFrame(reviews[['FILM','RT_user_norm','Metacritic_user_nom','IMDB_norm','Fandango_Ratingvalue','Fandango_Stars']])
norm_reviews.iloc[[0],:]
##print(norm_reviews[0:2])
# Out:
#                              FILM  RT_user_norm  Metacritic_user_nom  \
# 0  Avengers: Age of Ultron (2015)           4.3                 3.55
#
#    IMDB_norm  Fandango_Ratingvalue  Fandango_Stars
# 0        3.9                   4.5             5.0

# %%
#create a bars from a value of a row in reviews onto a figure and axes, declare fig and axes using shortcut with plt.subplots
#axes.bar takes list like values for x (position of bars) and y(heights of the bars) and a scalar value for width
#use numpy arange to create a list of values which become the bar positions and start the first bar with its center at 0.75, they will be evenly spaced
num_cols = ['RT_user_norm', 'Metacritic_user_nom', 'IMDB_norm', 'Fandango_Ratingvalue', 'Fandango_Stars']

bar_heights = norm_reviews[num_cols].iloc[0].values
bar_positions = arange(5) + 0.75

fig, ax = plt.subplots()
ax.bar(bar_positions,bar_heights, 0.5)
# Out:
# <BarContainer object of 5 artists>

# %%
#set the ticks on the x axis to their positions, set xticks' labels and rotate them 90 degrees, and set x-axis label. Set the title of the y-axes and axes
num_cols = ['RT_user_norm', 'Metacritic_user_nom', 'IMDB_norm', 'Fandango_Ratingvalue', 'Fandango_Stars']
bar_heights = norm_reviews[num_cols].iloc[0].values
bar_positions = arange(5) + 0.75
tick_positions = range(1,6)

fig, ax = plt.subplots()
ax.bar(bar_positions,bar_heights, 0.5)
ax.set_xticks(tick_positions)
ax.set_xticklabels(num_cols, rotation=90)
ax.set_xlabel("Rating Source")

ax.set_ylabel("Average Rating")
ax.set_title("Average User Rating For Avengers: Age of Ultron (2015)")

plt.show()

# %% [markdown]
# <h2>Horizontal bar plot

# %%
#same approach and methods just for axes.barh for horizontal bar plot
num_cols = ['RT_user_norm', 'Metacritic_user_nom', 'IMDB_norm', 'Fandango_Ratingvalue', 'Fandango_Stars']

bar_widths = norm_reviews[num_cols].iloc[0].values
bar_positions = arange(5) + 0.75
tick_positions = range(1,6)

fig, ax = plt.subplots()
ax.barh(bar_positions,bar_widths,0.5)
ax.set_yticks(tick_positions)
ax.set_yticklabels(num_cols)
ax.set_ylabel("Rating Source")
ax.set_xlabel("Average Rating")
ax.set_title("Average User Rating For Avengers: Age of Ultron (2015)")
plt.show()

# %% [markdown]
# <h2>Scatter Plots

# %%
fig, ax = plt.subplots()
ax.scatter(norm_reviews['Fandango_Ratingvalue'], norm_reviews['RT_user_norm'])
ax.set_xlabel("Fandango")
ax.set_ylabel("Rotten Tomatoes")
plt.show()

# %%
fig = plt.figure(figsize=(5,10))
ax1 = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2)
reviews = pd.read_csv('fandango_score_comparison.csv')
cols = ['FILM', 'RT_user_norm', 'Metacritic_user_nom', 'IMDB_norm', 'Fandango_Ratingvalue', 'Fandango_Stars']
norm_reviews = reviews[cols]
ax1.scatter(norm_reviews['Fandango_Ratingvalue'],norm_reviews['RT_user_norm'])
ax1.set_xlabel("Fandango")
ax1.set_ylabel("Rotten Tomatoes")

ax2.scatter(norm_reviews['RT_user_norm'], norm_reviews['Fandango_Ratingvalue'])
ax2.set_xlabel("Rotten Tomatoes")
ax2.set_ylabel("Fandango")
# Out:
# Text(0, 0.5, 'Fandango')

# %%
fig = plt.figure(figsize=(5,10))
ax1 = fig.add_subplot(3,1,1)
ax2 = fig.add_subplot(3,1,2)
ax3 = fig.add_subplot(3,1,3)

ax1.scatter(norm_reviews["Fandango_Ratingvalue"], norm_reviews["RT_user_norm"])
ax1.set_xlabel("Fandango")
ax1.set_ylabel("Rotten Tomatoes")
ax1.set_xlim(0,5)
ax1.set_ylim(0,5)

ax2.scatter(norm_reviews["Fandango_Ratingvalue"], norm_reviews["Metacritic_user_nom"])
ax2.set_xlabel("Fandango")
ax2.set_ylabel("Metacritic")
ax2.set_xlim(0,5)
ax2.set_ylim(0,5)

ax3.scatter(norm_reviews["Fandango_Ratingvalue"], norm_reviews['IMDB_norm'])
ax3.set_xlabel("Fandango")
ax3.set_ylabel("IMDB")
ax3.set_xlim(0,5)
ax3.set_ylim(0,5)
plt.show()

# %% [markdown]
# <h2>Histograms and Boxplots

# %%
reviews = pd.read_csv('fandango_score_comparison.csv')
cols = ['FILM', 'RT_user_norm', 'Metacritic_user_nom', 'IMDB_norm', 'Fandango_Ratingvalue']
norm_reviews = reviews[cols]
print(norm_reviews[:5])
# Out:
#                              FILM  RT_user_norm  Metacritic_user_nom  \
# 0  Avengers: Age of Ultron (2015)           4.3                 3.55
# 1               Cinderella (2015)           4.0                 3.75
# 2                  Ant-Man (2015)           4.5                 4.05
# 3          Do You Believe? (2015)           4.2                 2.35
# 4   Hot Tub Time Machine 2 (2015)           1.4                 1.70
#
#    IMDB_norm  Fandango_Ratingvalue
# 0       3.90                   4.5
# 1       3.55                   4.5
# 2       3.90                   4.5
# 3       2.70                   4.5
# 4       2.55                   3.0

# %%
fandango_distribution = norm_reviews['Fandango_Ratingvalue'].value_counts().sort_index()

imdb_distribution = norm_reviews['IMDB_norm'].value_counts().sort_index()

print(fandango_distribution)
print(imdb_distribution)
# Out:
# 2.7     2
# 2.8     2
# 2.9     5
# 3.0     4
# 3.1     3
# 3.2     5
# 3.3     4
# 3.4     9
# 3.5     9
# 3.6     8
# 3.7     9
# 3.8     5
# 3.9    12
# 4.0     7
# 4.1    16
# 4.2    12
# 4.3    11
# 4.4     7
# 4.5     9
# 4.6     4
# 4.8     3
# Name: Fandango_Ratingvalue, dtype: int64
# 2.00     1
# 2.10     1
# 2.15     1
# 2.20     1
# 2.30     2
# 2.45     2
# 2.50     1
# 2.55     1
# 2.60     2
# 2.70     4
# 2.75     5
# 2.80     2
# 2.85     1
# 2.90     1
# 2.95     3
# 3.00     2
# 3.05     4
# 3.10     1
# 3.15     9
# 3.20     6
# 3.25     4
# 3.30     9
# 3.35     7
# 3.40     1
# 3.45     7
# 3.50     4
# 3.55     7
# 3.60    10
# 3.65     5
# 3.70     8
# 3.75     6
# 3.80     3
# 3.85     4
# 3.90     9
# 3.95     2
# 4.00     1
# 4.05     1
# 4.10     4
# 4.15     1
# 4.20     2
# 4.30     1
# Name: IMDB_norm, dtype: int64

# %%
#simple frequency distribution of fandango ratings ranging from 0 to 5
fig, ax = plt.subplots()
ax.hist(norm_reviews['Fandango_Ratingvalue'], range=(0,5))
plt.show()

# %% [markdown]
# We can visually examine the proportional area that the bars in the 2.0 to 4.0 range take up and determine that more than 50% of the movies on Fandango fall in this range. We can increase the number of bins from 10 to 20 for improved resolution of the distribution. The length of each bin will be 0.25 (5 / 20) instead of 0.5 (5 / 10). The bins parameter for Axes.hist() is the 2nd positional parameter, but can also be specified as a named parameter:

# %% [markdown]
#  To ensure that the scales for the y-axis are the same for all histograms, let's set them manually using Axes.set_ylim().

# %%
#generate histograms with different number of bins and ranges 
fig = plt.figure(figsize=(5,20))
ax1 = fig.add_subplot(4,1,1)
ax2 = fig.add_subplot(4,1,2)
ax3 = fig.add_subplot(4,1,3)
ax4 = fig.add_subplot(4,1,4)

ax1.hist(norm_reviews['Fandango_Ratingvalue'],bins=20,range=(0,5))
ax2.hist(norm_reviews['RT_user_norm'],bins=20,range=(0,5))
ax3.hist(norm_reviews['Metacritic_user_nom'],bins=20,range=(0,5))
ax4.hist(norm_reviews['IMDB_norm'],bins=20,range=(0,5))

ax1.set_ylim(0,50)
ax2.set_ylim(0,50)
ax3.set_ylim(0,50)
ax4.set_ylim(0,50)

ax1.set_title("Distribution of Fandango Ratings")
ax2.set_title("Distribution of Rotten Tomatoes Ratings")
ax3.set_title("Distribution of Metacritic Ratings")
ax4.set_title("Distribution of IMDB Ratings")

plt.show()

# %% [markdown]
# <h3>Our first box plot

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(filename = "boxplot_intro.png", width=600, height=600)

# %%
fig, ax = plt.subplots()

ax.boxplot(norm_reviews['RT_user_norm'])
ax.set_ylim(0,5)
ax.set_xticklabels(['Rotten Tomatoes'])
plt.show()
